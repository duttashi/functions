# %% [markdown]
# The Wifi routers generated log files in `*.db` format. That is the log files were in database format.
#
# The objective was to read the database file and conevrt it to `.csv` format.

# %%
# load the required libraries
import sqlite3
from sqlite3 import Error
import os
import glob

# %% [markdown]
# Give the full path to file location. Else there will be an error, `OperationalError: unable to open database file`. See this [SO post answer](https://stackoverflow.com/questions/4636970/sqlite3-operationalerror-unable-to-open-database-file) by user `jhc`

# %%
dataPath = "C:\\Users\\Ashoo\\Documents\\Python Playground\\functions\\data\\wifi_19-01-01_03_56.db"

# %%
# create database connection
conn = sqlite3.connect(dataPath)

# %%
# a custom function to create database connection
# Reference: http://www.sqlitetutorial.net/sqlite-python/sqlite-python-select/
def create_connection(db_file):
    try:
        conn = sqlite3.connect(db_file)
        return conn
    except Error as e:
        print(e)
 
    return None

# %%
# create a function for reading the Wifi table
def read_write_wifi_tbl_to_csv(conn):
    cur = conn.cursor()
    query='select * from WIFI'
    data=pd.read_sql(query,conn)
    data.to_csv('wifiTbl.csv')

# %%
def main():
    
    conn = create_connection(dataPath)
    with conn:
               
        print("Read the db file and wrote to disc in csv format")
        read_write_wifi_tbl_to_csv(conn)
 
# Execute the main function 
if __name__ == '__main__':
    main()
# Out:
# Read the db file and wrote to disc in csv format

# %%
cwd = os.getcwd()  # Get the current working directory (cwd)
# Out:
# Files in 'C:\Users\Ashoo\Documents\Python Playground\functions\scripts': ['.ipynb_checkpoints', 'convert_db_to_csv.ipynb', 'convert_sqlite_to_csv.ipynb', 'function_LeapYear.ipynb', 'Jupyter notebook tips and tricks.ipynb', 'Lists and Dictionaries.ipynb', 'notebook for installing packages.ipynb', 'python fundamentals.ipynb', 'road_traffic.R', 'sensor_meter_eda.R', 'wifiTbl.csv', 'working with strings in python.ipynb', 'Working with Text.ipynb']

# %%
# change the current working directory
print (os.getcwd())  # Prints the current working directory
# To set the working directory
os.chdir('C:\\Users\Ashoo\\Documents\\Python Playground\\functions')
print (os.getcwd())
# Out:
# C:\Users\Ashoo\Documents\Python Playground\functions
# C:\Users\Ashoo\Documents\Python Playground\functions

# %%
files = os.listdir(os.getcwd())  # Get all the files in that directory
print("Files in '%s': %s" % (os.getcwd(), files))
# Out:
# Files in 'C:\Users\Ashoo\Documents\Python Playground\functions': ['.git', '.gitignore', '.Rhistory', '.Rproj.user', 'CONTRIBUTING.md', 'data', 'Functions.Rproj', 'LICENSE', 'README.md', 'scripts']

# %%
datadir = os.path.join(os.getcwd(), 'data')
print(datadir)
# Out:
# C:\Users\Ashoo\Documents\Python Playground\functions\data

# %% [markdown]
# ### Note:
#
# - When reading or opening a csv file ensure the `open()` has encoding set to `utf8`.
# - When reading a sqlite db file, ensure the `open()` has encoding set to `utf_8`. if this does not work, then add `errors='ignore`

# %%
file_list = glob.glob(os.path.join(os.getcwd(), "data", "*.db"))
corpus = []

for file_path in file_list:
    with open(file_path, errors='ignore') as f_input:
        corpus.append(f_input.read())

print (corpus)
# Out:
# ['SQLite format 3\x00\x04\x00\x01\x01\x00@  -æ\x07\n\x03ü\x00\x02\x02ž\x00\x02ž\x03×\x
# ...
